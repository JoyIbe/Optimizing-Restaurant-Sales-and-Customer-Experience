# %% [markdown]
# # Task: Restaurant Sales Analysis

# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\IVANN\Downloads\restaurant_data.csv")
df
# Out:
#                  Name  Location   Cuisine  Rating  Seating Capacity  \
# 0        Restaurant 0     Rural  Japanese     4.0                38
# 1        Restaurant 1  Downtown   Mexican     3.2                76
# 2        Restaurant 2     Rural   Italian     4.7                48
# 3        Restaurant 3     Rural   Italian     4.4                34
# 4        Restaurant 4  Downtown  Japanese     4.9                88
# ...               ...       ...       ...     ...               ...
# 8363  Restaurant 8363  Suburban    Indian     3.4                54
# 8364  Restaurant 8364     Rural    Indian     3.7                49
# 8365  Restaurant 8365  Downtown   Italian     4.7                88
# 8366  Restaurant 8366     Rural  American     3.1                31
# 8367  Restaurant 8367     Rural  Japanese     4.0                33
#
#       Average Meal Price  Marketing Budget  Social Media Followers  \
# 0                  73.98              2224                   23406
# ...

# %%
# Checking for null values

df.isnull().sum()
# Out:
# Name                      0
# Location                  0
# Cuisine                   0
# Rating                    0
# Seating Capacity          0
# Average Meal Price        0
# Marketing Budget          0
# Social Media Followers    0
# Chef Experience Years     0
# Number of Reviews         0
# Avg Review Length         0
# Ambience Score            0
# Service Quality Score     0
# Parking Availability      0
# Weekend Reservations      0
# Weekday Reservations      0
# Revenue                   0
# dtype: int64

# %%
# Checking concise summary of the data

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8368 entries, 0 to 8367
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Name                    8368 non-null   object
#  1   Location                8368 non-null   object
#  2   Cuisine                 8368 non-null   object
#  3   Rating                  8368 non-null   float64
#  4   Seating Capacity        8368 non-null   int64
#  5   Average Meal Price      8368 non-null   float64
#  6   Marketing Budget        8368 non-null   int64
#  7   Social Media Followers  8368 non-null   int64
#  8   Chef Experience Years   8368 non-null   int64
#  9   Number of Reviews       8368 non-null   int64
#  10  Avg Review Length       8368 non-null   float64
#  11  Ambience Score          8368 non-null   float64
#  12  Service Quality Score   8368 non-null   float64
#  13  Parking Availability    8368 non-null   object
# ...

# %%
# Checking for duplicates 

df[df.duplicated(keep=False)]

# No duplicate values
# Out:
# Empty DataFrame
# Columns: [Name, Location, Cuisine, Rating, Seating Capacity, Average Meal Price, Marketing Budget, Social Media Followers, Chef Experience Years, Number of Reviews, Avg Review Length, Ambience Score, Service Quality Score, Parking Availability, Weekend Reservations, Weekday Reservations, Revenue]
# Index: []

# %%
# Checking descriptive statistics across all numerical values

df.describe()
# Out:
#             Rating  Seating Capacity  Average Meal Price  Marketing Budget  \
# count  8368.000000       8368.000000         8368.000000       8368.000000
# mean      4.008258         60.212835           47.896659       3218.254900
# std       0.581474         17.399488           14.336767       1824.896053
# min       3.000000         30.000000           25.000000        604.000000
# 25%       3.500000         45.000000           35.490000       1889.000000
# 50%       4.000000         60.000000           45.535000       2846.500000
# 75%       4.500000         75.000000           60.300000       4008.500000
# max       5.000000         90.000000           76.000000       9978.000000
#
#        Social Media Followers  Chef Experience Years  Number of Reviews  \
# count             8368.000000            8368.000000        8368.000000
# mean             36190.621773              10.051984         523.010397
# std              18630.153330               5.516606         277.215127
# ...

# %%
df.head(5)
# Out:
#            Name  Location   Cuisine  Rating  Seating Capacity  \
# 0  Restaurant 0     Rural  Japanese     4.0                38
# 1  Restaurant 1  Downtown   Mexican     3.2                76
# 2  Restaurant 2     Rural   Italian     4.7                48
# 3  Restaurant 3     Rural   Italian     4.4                34
# 4  Restaurant 4  Downtown  Japanese     4.9                88
#
#    Average Meal Price  Marketing Budget  Social Media Followers  \
# 0               73.98              2224                   23406
# 1               28.11              4416                   42741
# 2               48.29              2796                   37285
# 3               51.55              1167                   15214
# 4               75.98              3639                   40171
#
#    Chef Experience Years  Number of Reviews  Avg Review Length  \
# 0                     13                185         161.924906
# 1                      8                533         148.759717
# ...

# %% [markdown]
# # Key questions to address

# %% [markdown]
# ### Top 5 restaurants by Revenue

# %%
#Top 5 restaurants by Revenue

df.groupby('Name')['Revenue'].sum().sort_values(ascending=False).head(5)
# Out:
# Name
# Restaurant 4324    1531867.55
# Restaurant 7093    1518965.19
# Restaurant 3952    1515593.10
# Restaurant 5431    1515520.96
# Restaurant 2196    1509391.07
# Name: Revenue, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings 
warnings.filterwarnings('ignore')

# %%
# Visualizing the top 5 restuarant

restuarant=df.groupby('Name')['Revenue'].sum().sort_values(ascending=False).head(5)

plot = sns.barplot(data=restuarant, palette=sns.color_palette('tab10'))
for bars in plot.containers:
    plot.bar_label(bars, [f'{x:.2f}' for x in bars.datavalues])
plot.set_xlabel('Restuarants')
plot.set_ylabel('Total Revenue')   
plt.title('Top 5 restaurants by Revenue')
plt.xticks(rotation=45, ha='right')
plt.show

# Outcome: 
print("""
Insight:The highest-earning restaurant is Restaurant 4324, with a revenue of about $1,531,867.55.
The other four restaurants follow closely behind, with revenues ranging from $1,509,391.07 to $1,518,965.19.""")
# Out:
# Insight:The highest-earning restaurant is Restaurant 4324, with a revenue of about $1,531,867.55.
# The other four restaurants follow closely behind, with revenues ranging from $1,509,391.07 to $1,518,965.19.

# %% [markdown]
# ### 5 most rated restaurants

# %%
# Grouping restuarants by the highest ratings on average

df.groupby('Name')['Rating'].mean().sort_values(ascending=False).head(5)
# Out:
# Name
# Restaurant 7500    5.0
# Restaurant 7744    5.0
# Restaurant 7680    5.0
# Restaurant 7682    5.0
# Restaurant 7689    5.0
# Name: Rating, dtype: float64

# %%
# Visualizing 

rated_restuarant = df.groupby('Name')['Rating'].mean().sort_values(ascending=False).head(5)

plt.figure(figsize=(20, 7)) # manipulating its size

plt.bar(rated_restuarant.index, rated_restuarant.values)
plt.xlabel('Name')
plt.ylabel('Average Rating')
plt.title('5 most rated restuarants by Average Rating', fontsize=15)
plt.xticks(rotation=45, ha='right')
plt.show()

# Outcome: 
print('Insight:Restaurants with the most highest ratings on average is Restaurant 7500, Restuarant 7744,7680, 7682 with all having a ratings of 5.0')
# Out:
# Insight:Restaurants with the most highest ratings on average is Restaurant 7500, Restuarant 7744,7680, 7682 with all having a ratings of 5.0

# %% [markdown]
# ### Carry out EDA to find the relation between revenue and features of the dataset.

# %%
# Calculating the correlation between rating and revenue generated

correlation_matrix = df[['Revenue', 'Rating']].corr()
correlation_matrix
# Out:
#           Revenue    Rating
# Revenue  1.000000  0.009899
# Rating   0.009899  1.000000

# %%
# Visualizing the correlation between rating and revenue generated

correlation_matrix = df[['Revenue', 'Rating']].corr()

plt.figure(figsize=(6, 4))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=1.5)
plt.title("Correlation Between Revenue and Ratings")
plt.show()

print("""
Insight: There is no relationship between a restaurant’s revenue and its rating.
This indicates that high ratings do not necessarily lead to high revenue.
""")
# Out:
# Insight: There is no relationship between a restaurant’s revenue and its rating.
# This indicates that high ratings do not necessarily lead to high revenue.

# %%
df.head(5)
# Out:
#            Name  Location   Cuisine  Rating  Seating Capacity  \
# 0  Restaurant 0     Rural  Japanese     4.0                38
# 1  Restaurant 1  Downtown   Mexican     3.2                76
# 2  Restaurant 2     Rural   Italian     4.7                48
# 3  Restaurant 3     Rural   Italian     4.4                34
# 4  Restaurant 4  Downtown  Japanese     4.9                88
#
#    Average Meal Price  Marketing Budget  Social Media Followers  \
# 0               73.98              2224                   23406
# 1               28.11              4416                   42741
# 2               48.29              2796                   37285
# 3               51.55              1167                   15214
# 4               75.98              3639                   40171
#
#    Chef Experience Years  Number of Reviews  Avg Review Length  \
# 0                     13                185         161.924906
# 1                      8                533         148.759717
# ...

# %%
# Calculating locations that generates the most revenue

df.groupby('Location')['Revenue'].sum().sort_values(ascending=False)
# Out:
# Location
# Downtown    2.444628e+09
# Suburban    1.802033e+09
# Rural       1.243337e+09
# Name: Revenue, dtype: float64

# %%
# Visualizing locations that generates the most revenue

location=df.groupby('Location')['Revenue'].sum().sort_values(ascending=False)

plt.figure(figsize=(10, 7))

plot = sns.barplot(data=location, palette=sns.color_palette('tab10'))
for bars in plot.containers:
    plot.bar_label(bars, [f'{x:.2f}' for x in bars.datavalues])
plot.set_xlabel('Location')
plot.set_ylabel('Total Revenue')   
plt.title('Top Location that generates the Highest Revenue')
plt.xticks(rotation=45, ha='right')
plt.show

# Outcome: 
print("""
Insight: Downtown is the highest generating location and shows a significant gap compared to Suburban and Rural regions. 
Leveraging on this location will boost sales and revenue growth and also improves brand visibility. 
""")
# Out:
# Insight: Downtown is the highest generating location and shows a significant gap compared to Suburban and Rural regions.
# Leveraging on this location will boost sales and revenue growth and also improves brand visibility.

# %%
# Calculating Cuisine that generates the most revenue

df.groupby('Cuisine')['Revenue'].sum().sort_values(ascending=False)
# Out:
# Cuisine
# Japanese    1.260630e+09
# French      1.175352e+09
# Italian     9.788450e+08
# American    7.999579e+08
# Indian      6.798669e+08
# Mexican     5.953458e+08
# Name: Revenue, dtype: float64

# %%
# Visualizing Cuisine that generates the most revenue

cuisine = df.groupby('Cuisine')['Revenue'].sum().sort_values(ascending=False)

plt.figure(figsize=(10, 7))

plot = sns.barplot(data=cuisine, palette=sns.color_palette('tab10'))
for bars in plot.containers:
    plot.bar_label(bars, [f'{x:.2f}' for x in bars.datavalues])
plot.set_xlabel('Cuisine')
plot.set_ylabel('Total Revenue')   
plt.title('Top Cuisine that generates the Highest Revenue')
plt.xticks(rotation=45, ha='right')
plt.show

# Outcome: 
print('Insight: Japanese cuisine leads with a total revenue, french, italian follows closely. This shows highly profitable cuisines choices.')
# Out:
# Insight: Japanese cuisine leads with a total revenue, french, italian follows closely. This shows highly profitable cuisines choices.

# %%
# Checking the relationship between revenue across significant numeric features

numeric_df=df.corr(numeric_only=True)
numeric_df
# Out:
#                           Rating  Seating Capacity  Average Meal Price  \
# Rating                  1.000000          0.004862           -0.002265
# Seating Capacity        0.004862          1.000000           -0.028809
# Average Meal Price     -0.002265         -0.028809            1.000000
# Marketing Budget        0.263448          0.509560           -0.002054
# Social Media Followers  0.289559          0.496917           -0.005753
# Chef Experience Years   0.022192          0.010324            0.000401
# Number of Reviews      -0.004238         -0.016100            0.001802
# Avg Review Length      -0.001272         -0.032670            0.016013
# Ambience Score          0.007099          0.002842           -0.001094
# Service Quality Score   0.000887         -0.006400            0.011714
# Weekend Reservations   -0.000274          0.437416           -0.018072
# Weekday Reservations    0.001706          0.418636           -0.027837
# ...

# %%
sns.heatmap(numeric_df.corr(), annot =True)

plt.rcParams['figure.figsize'] = (30,20)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
print("""
Insight:
There is a very strong positive correlation between Revenue and Seating Capacity (0.71), meaning bigger seating capacity leads to higher revenue.
There is a very strong positive correlation between Revenue and Average Meal Price (0.68), meaning higher meal prices result in higher revenue.
Revenue and Marketing Budget (0.38): A moderate positive correlation, meaning spending more on marketing generally increases revenue.
Revenue and Social Media Followers (0.37) shows a moderate positive correlation, meaning more social media followers help increase revenue.
Revenue and Weekend Reservations (0.37): More weekend reservations lead to higher revenue.
Revenue and Weekday Reservations (0.34): More weekday reservations also increase revenue.
""")
# Out:
# Insight:
# There is a very strong positive correlation between Revenue and Seating Capacity (0.71), meaning bigger seating capacity leads to higher revenue.
# There is a very strong positive correlation between Revenue and Average Meal Price (0.68), meaning higher meal prices result in higher revenue.
# Revenue and Marketing Budget (0.38): A moderate positive correlation, meaning spending more on marketing generally increases revenue.
# Revenue and Social Media Followers (0.37) shows a moderate positive correlation, meaning more social media followers help increase revenue.
# Revenue and Weekend Reservations (0.37): More weekend reservations lead to higher revenue.
# Revenue and Weekday Reservations (0.34): More weekday reservations also increase revenue.
